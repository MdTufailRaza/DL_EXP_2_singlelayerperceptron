# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("/content/lung cancer survey.csv")
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES
#
# [309 rows x 16 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
data["ANXIETY"]=encode.fit_transform(data["ANXIETY"])
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        1              1
# 1        M   74        2               1        0              1
# 2        F   59        1               1        0              2
# 3        M   63        2               2        1              1
# 4        F   63        1               2        0              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        0              2
# 305      M   70        2               1        0              1
# 306      M   58        2               1        0              1
# 307      M   67        2               1        1              1
# 308      M   62        1               1        0              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES
#
# [309 rows x 16 columns]

# %%
X=data[data.columns[2:4]][:50]
X
# Out:
#     SMOKING  YELLOW_FINGERS
# 0         1               2
# 1         2               1
# 2         1               1
# 3         2               2
# 4         1               2
# 5         1               2
# 6         2               1
# 7         2               2
# 8         2               1
# 9         2               2
# 10        2               2
# 11        1               1
# 12        2               1
# 13        2               1
# 14        2               1
# 15        1               2
# 16        2               1
# 17        2               2
# 18        2               2
# 19        1               1
# 20        2               2
# 21        1               2
# 22        2               1
# 23        2               1
# 24        2               2
# 25        1               2
# 26        2               2
# 27        1               1
# 28        2               2
# 29        1               2
# 30        2               2
# 31        2               1
# 32        2               2
# 33        2               2
# 34        1               2
# 35        2               2
# 36        1               2
# 37        1               1
# 38        2               1
# 39        2               1
# 40        2               1
# 41        1               1
# 42        1               2
# 43        2               1
# 44        2               2
# 45        2               2
# 46        2               2
# 47        2               2
# 48        1               1
# 49        1               1

# %%
y=data["ANXIETY"][:50]
X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.4,random_state=20)
X_train = np.array(X_train, dtype=float)

# %%
plt.title("Plot GRAPH")
plt.scatter(X[y==0]["SMOKING"],X[y==0]["YELLOW_FINGERS"],color="yellow")
plt.scatter(X[y==0]["SMOKING"],X[y==0]["YELLOW_FINGERS"],color="red")
plt.legend()
plt.plot()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# []

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
n_hidden=50
n_epochs=100
learning_rate=2

# %%
weights_hidden=np.random.normal(0.0,size=(X_train.shape[1],n_hidden))
weights_output=np.random.normal(0.0,size=(n_hidden))

# %%
hist_loss=[]
hist_accuracy=[]
print(weights_hidden)
print(weights_output)
# Out:
# [[-1.24822197e+00 -1.37038457e+00 -4.42564003e-01 -1.38970019e+00
#   -1.36512110e+00 -8.46440834e-01 -3.06193177e-01  1.00449435e+00
#    7.05613676e-01  1.17811795e+00 -1.21473939e+00 -1.05880543e-01
#    2.26696947e+00 -1.01572317e-01 -3.34911625e-01 -1.16783047e+00
#    1.89912075e-01  1.02271851e+00 -3.11166123e-01  2.08007039e-01
#   -2.43009580e-01  3.45365519e-01  1.09915779e-01  1.68807822e+00
#   -3.24412745e-01  1.49010543e+00  9.04320225e-01  1.67447769e+00
#   -2.03197954e+00  1.03630539e+00  8.05118769e-01  1.73237377e+00
#   -7.95045303e-02 -9.50081794e-02 -4.74683033e-01 -8.32914262e-01
#    1.67206081e+00 -1.67387149e-01 -1.85581683e-01 -1.72844421e+00
#    1.02930258e+00  1.95521224e-01  1.28303734e+00  1.21796225e+00
#    5.50649451e-01  6.27192090e-01 -1.18386378e+00 -3.74005318e-01
#    6.35603338e-01 -1.00720451e+00]
#  [-1.35969213e+00 -1.10471102e+00  5.67156761e-01  9.39433319e-02
#   -2.13509062e-01  1.04830342e+00  3.63891675e-02  1.83724648e-01
#   -1.13581102e+00 -1.71769222e-01 -4.77102296e-01 -1.01796918e+00
#   -3.03638752e-01 -9.69778410e-01 -3.84703155e-01  2.53553618e-02
#   -1.68674702e-01  4.79936126e-01  1.24775897e+00 -1.77312495e+00
#    2.85384920e-02 -1.13840980e+00  1.13256600e+00 -1.70346187e+00
#    3.31626351e-01  1.58032928e-01 -1.29952144e+00  2.54266503e-01
#   -3.22504731e-01  2.91817716e+00  1.29289818e+00  6.01785266e-02
#   -7.13755555e-01  2.87121219e+00 -2.94434411e+00 -1.60651224e+00
#    7.58472689e-01 -4.86616324e-01  2.64740893e-03  3.81188130e-01
#    6.65513926e-01  2.09187338e-01 -1.12541705e-02 -1.56047731e+00
#   -1.34278030e+00  5.42705606e-01 -9.80864934e-02 -4.40944550e-01
#    2.08319744e-02 -1.93808061e-01]]
# [ 0.38597154  0.01755557 -1.12487046  0.18529385 -0.80883473  0.4942427
#  -1.56223377  0.29873664 -0.40084898 -0.49219949  0.51229619  0.28937623
#  -2.45028157  1.98405345 -0.37094837 -0.13090877  0.15529447  2.09129836
#   0.97429286 -0.33562967 -1.59494224 -0.75098853  0.77674855  1.35518224
#   0.1340917  -0.56285933  2.0962805   0.74116347  0.28029522 -0.67178954
#  -0.34274653  0.59036741 -0.91756452  0.23130147  0.2491661  -0.82503824
#  -1.18669641  0.58015199 -0.18180751 -1.33856174  0.70185925  0.90194338
#   1.37656945  1.19776384  0.23234267  0.49976209 -1.08308439 -0.48057509
#   0.06942775 -1.17665511]

# %%
for i in range(n_epochs):
    del_w_hidden=np.zeros(weights_hidden.shape)
    del_w_output=np.zeros(weights_output.shape)

    for x1,y1 in zip(X_train,y_train):
        hidden_input=np.dot(x1,weights_hidden)
        hidden_output=sigmoid(hidden_input)
        output_summation=np.dot(hidden_output,weights_output)
        output_activation=sigmoid(output_summation)

        error=y1-output_activation
        output_error=error*output_activation*(1-output_activation)
        hidden_error=np.dot(output_error,weights_output)*hidden_output*(1-hidden_output)
        del_w_hidden+=hidden_error*x1[:,None]
        del_w_output+=output_error*hidden_output

    weights_hidden+=learning_rate*del_w_hidden/X_train.shape[0]
    weights_output+=learning_rate*del_w_output/X_train.shape[0]

    if i%10==0:
        hidden_output=sigmoid(np.dot(X_val,weights_hidden))
        out=sigmoid(np.dot(hidden_output,weights_output))
        loss=np.mean((out-y_val)**2)
        predictions=out>0.5
        accuracy=np.mean(predictions==y_val)
        print(f'Epoch {i}, Loss: {loss.round(4)}, Accuracy: {accuracy}')
# Out:
# Epoch 0, Loss: 0.1992, Accuracy: 0.75
# Epoch 10, Loss: 0.1987, Accuracy: 0.75
# Epoch 20, Loss: 0.1983, Accuracy: 0.75
# Epoch 30, Loss: 0.1979, Accuracy: 0.75
# Epoch 40, Loss: 0.1977, Accuracy: 0.75
# Epoch 50, Loss: 0.1974, Accuracy: 0.75
# Epoch 60, Loss: 0.1972, Accuracy: 0.75
# Epoch 70, Loss: 0.1971, Accuracy: 0.75
# Epoch 80, Loss: 0.197, Accuracy: 0.75
# Epoch 90, Loss: 0.1969, Accuracy: 0.75
